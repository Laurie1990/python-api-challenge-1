# %% [markdown]
# # WeatherPy
# ----
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your first objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# After each plot add a sentence or too explaining what the code is and analyzing.
#
# Your next objective is to run linear regression on each relationship, only this time separating them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude
#
# After each pair of plots explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have.
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %% [markdown]
# ##### Hints and Considerations
#
# * The city data you generate is based on random coordinates as well as different query times; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy). Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!
#
# * Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?
#
# * In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).
#
# * Once you have computed the linear regression for one chart, the process will be similar for all others. As a bonus, try to create a function that will create these charts based on different parameters.
#
# * Remember that each coordinate will trigger a separate call to the Google API. If you're creating your own criteria to plan your vacation, try to reduce the results in your DataFrame to 10 or fewer cities.
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Test of the citypy package
#lat_lng = str(input(f'Enter latitude and longtitude in form (lat,lng):'))
#lat,lng = lat_lng.split(',')
#city = citipy.nearest_city(float(lat), float(lng))
#set(dir(city))
#print(f"The cooridinates {lat},{lng} nearest city is: {city.city_name},{city.country_code}")

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

city_country = zip(cities,countries)
# Print the city count to confirm sufficient count
#print([i for i in city_country])
print(len(cities))
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).
# * Export the city data into a .csv.

# %%
# Test of the API call and verification correct data is returned
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city = "grajau"
country_code = "br"
query_url = f"{url}appid={api_key}&q={city},{country_code}&units={units}"
response = requests.get(query_url).json()
print(query_url)

cityID = int(response['id'])
cityName = response['name']
countryCode = str(response['sys']['country'])
lat_val = float(response['coord']['lat'])
lon_val = float(response['coord']['lon'])
weatherDate = (datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
temperature = float(response['main']['temp'])
humidity_val = float(response['main']['humidity'])
cloudiness_val = float(response['clouds']['all'])
windSpeed = float(response['wind']['speed'])

print(f"The weather date information received is: {weatherDate}")
print(f"The humidity information received is: {humidity_val}")
print(f"The clouds information received is: {cloudiness_val}")
print(f"The wind speed information received is: {windSpeed}")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6a6e5292617349bd250145ca6faa12c5&q=grajau,br&units=imperial
# The weather date information received is: 01/24/20
# The humidity information received is: 86.0
# The clouds information received is: 100.0
# The wind speed information received is: 1.83

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up lists to hold reponse info
city_id = []
city_name = []
country = []
latitude = []
longitude = []
weather_date = []
temp = []
humidity = []
cloudiness = []
wind_speed = []

# Open file to write results of API calls - success or not into a txt file, as well as all data pulled into a csv
myprintlog = open('weatherAPI_printlog.txt', 'w')
myAPIdata = open('weatherAPI_data.csv', 'w')
# Write header line for csv file
myAPIdata.write("city_id,city_name,country,latitude,longitude,weather_date,temp,humidity,cloudiness,wind_speed\n")

# Loop through the list of tuples of cities,country codes and perform a request for data on each
for city,country_code in city_country:
    query_url = f"{url}appid={api_key}&q={city},{country_code}&units={units}"
    response = requests.get(query_url).json()

    # Try to grab the temp,humidity,cloudiness and wind speed if they are available in the Weather API
    try:
        # Create variables for each response item and format to desired datatype
        cityID = int(response['id'])
        cityName = response['name']
        countryCode = response['sys']['country']
        lat_val = response['coord']['lat']
        lon_val = response['coord']['lon']
        weatherDate = (datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
        temperature = response['main']['temp']
        humidity_val = response['main']['humidity']
        cloudiness_val = response['clouds']['all']
        windSpeed = response['wind']['speed']
        
        # Append retreived values to lists above
        city_id.append(cityID)
        city_name.append(cityName)
        country.append(countryCode)
        latitude.append(lat_val)
        longitude.append(lon_val)
        weather_date.append(weatherDate)
        temp.append(temperature)
        humidity.append(humidity_val)
        cloudiness.append(cloudiness_val)
        wind_speed.append(windSpeed)
        
        # Output line to terminal to mark progress and store it to a print log text file
        print(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        myprintlog.write(f"{cityName} with city ID:{cityID} was found in the Weathermap API\n")
        
        # Output all retreived values to a csv file
        myAPIdata.write(f"{cityID},{cityName},{countryCode},{lat_val},{lon_val},{weatherDate},\
            {temperature},{humidity_val},{cloudiness_val},{windSpeed}\n")
        
    # Handle exceptions for a city that is not available in the Weather API
    except:
        
        print(f"{city},{country_code} was not found in the Weathermap API\n")
        myprintlog.write(f"{city},{country_code} was not found in the Weathermap API\n")
        
        # Append null values so lists are all the same length (later we will remove nulls from dataframe)
        city_id.append(None)
        city_name.append(None)
        country.append(None)
        latitude.append(None)
        longitude.append(None)
        weather_date.append(None)
        temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        pass
    
# Close the file handle after completion of the loop
myprintlog.close()
myAPIdata.close()
# Out:
# Camocim with city ID:3403687 was found in the Weathermap API
#
# Kielce with city ID:769250 was found in the Weathermap API
#
# Thompson with city ID:6165406 was found in the Weathermap API
#
# Hermanus with city ID:3366880 was found in the Weathermap API
#
# Richards Bay with city ID:962367 was found in the Weathermap API
#
# codrington,ag was not found in the Weathermap API
#
# Rio Gallegos with city ID:3838859 was found in the Weathermap API
#
# Resistencia with city ID:3429577 was found in the Weathermap API
#
# khonuu,ru was not found in the Weathermap API
#
# Inhapim with city ID:3461214 was found in the Weathermap API
#
# Tupik with city ID:2014836 was found in the Weathermap API
#
# Lebu with city ID:3883457 was found in the Weathermap API
#
# Puerto Ayora with city ID:3652764 was found in the Weathermap API
#
# Castro with city ID:3896218 was found in the Weathermap API
#
# Coyhaique with city ID:3894426 was found in the Weathermap API
#
# Meulaboh with city ID:1214488 was found in the Weathermap API
#
# Lynn Haven with city ID:4163049 was found in the Weathermap API
#
# Leningradskiy with city ID:2123814 was found in the Weathermap API
#
# Broken Hill with city ID:2173911 was found in the Weathermap API
#
# Mar del Plata with city ID:3430863 was found in the Weathermap API
#
# Villamontes with city ID:3901547 was found in the Weathermap API
#
# Pevek with city ID:2122090 was found in the Weathermap API
#
# Isangel with city ID:2136825 was found in the Weathermap API
#
# Kodiak with city ID:5866583 was found in the Weathermap API
#
# taolanaro,mg was not found in the Weathermap API
#
# tsihombe,mg was not found in the Weathermap API
#
# Fuerte Olimpo with city ID:3438102 was found in the Weathermap API
#
# Jamestown with city ID:3370903 was found in the Weathermap API
#
# Busselton with city ID:2075265 was found in the Weathermap API
#
# Rio Cuarto with city ID:3838874 was found in the Weathermap API
#
# Andenes with city ID:3163146 was found in the Weathermap API
#
# Buguruslan with city ID:571159 was found in the Weathermap API
#
# Noyabrsk with city ID:1496503 was found in the Weathermap API
#
# Souillac with city ID:933995 was found in the Weathermap API
#
# La Ronge with city ID:6050066 was found in the Weathermap API
#
# Kahului with city ID:5847411 was found in the Weathermap API
#
# Bluff with city ID:2206939 was found in the Weathermap API
#
# Broome with city ID:2075720 was found in the Weathermap API
#
# Lac du Bonnet with city ID:6014443 was found in the Weathermap API
#
# Provideniya with city ID:4031574 was found in the Weathermap API
#
# Wanning with city ID:1791779 was found in the Weathermap API
#
# Cape Town with city ID:3369157 was found in the Weathermap API
#
# Esso with city ID:2125711 was found in the Weathermap API
#
# mataura,pf was not found in the Weathermap API
#
# Zyryanovsk with city ID:1516438 was found in the Weathermap API
#
# Avarua with city ID:4035715 was found in the Weathermap API
#
# Hobart with city ID:2163355 was found in the Weathermap API
#
# Umm Lajj with city ID:100926 was found in the Weathermap API
#
# Saskylakh with city ID:2017155 was found in the Weathermap API
#
# katha,mm was not found in the Weathermap API
#
# Port Lincoln with city ID:2063036 was found in the Weathermap API
#
# Vestmannaeyjar with city ID:3412093 was found in the Weathermap API
#
# Ushuaia with city ID:3833367 was found in the Weathermap API
#
# Belyy Yar with city ID:1510377 was found in the Weathermap API
#
# Saint-Philippe with city ID:935215 was found in the Weathermap API
#
# Atuona with city ID:4020109 was found in the Weathermap API
#
# Qiongshan with city ID:1797535 was found in the Weathermap API
#
# Mahebourg with city ID:934322 was found in the Weathermap API
#
# Pangnirtung with city ID:6096551 was found in the Weathermap API
#
# Vaini with city ID:4032243 was found in the Weathermap API
#
# aflu,dz was not found in the Weathermap API
#
# Buriti Alegre with city ID:3468745 was found in the Weathermap API
#
# Komsomolets with city ID:1522348 was found in the Weathermap API
#
# Port Alfred with city ID:964432 was found in the Weathermap API
#
# Nabire with city ID:1634614 was found in the Weathermap API
#
# Dunedin with city ID:2191562 was found in the Weathermap API
#
# Fairbanks with city ID:5861897 was found in the Weathermap API
#
# Punta Arenas with city ID:3874787 was found in the Weathermap API
#
# Mlowo with city ID:153352 was found in the Weathermap API
#
# Olinda with city ID:3393536 was found in the Weathermap API
#
# Pisco with city ID:3932145 was found in the Weathermap API
#
# Dikson with city ID:1507390 was found in the Weathermap API
#
# Nikolskoye with city ID:546105 was found in the Weathermap API
#
# Severo-Kuril'sk with city ID:2121385 was found in the Weathermap API
#
# palabuhanratu,id was not found in the Weathermap API
#
# Corinto with city ID:3465512 was found in the Weathermap API
#
# Sakakah with city ID:102527 was found in the Weathermap API
#
# Kruisfontein with city ID:986717 was found in the Weathermap API
#
# Vao with city ID:2137773 was found in the Weathermap API
#
# Rikitea with city ID:4030556 was found in the Weathermap API
#
# Kaitangata with city ID:2208248 was found in the Weathermap API
#
# Turukhansk with city ID:1488903 was found in the Weathermap API
#
# urosevac,rs was not found in the Weathermap API
#
# Iskateley with city ID:866062 was found in the Weathermap API
#
# Port Blair with city ID:1259385 was found in the Weathermap API
#
# Albany with city ID:2077963 was found in the Weathermap API
#
# Trelew with city ID:3833883 was found in the Weathermap API
#
# Kapaa with city ID:5848280 was found in the Weathermap API
#
# Seymchan with city ID:2121373 was found in the Weathermap API
#
# Smithers with city ID:6149996 was found in the Weathermap API
#
# Mulchen with city ID:3879200 was found in the Weathermap API
#
# Hasaki with city ID:2112802 was found in the Weathermap API
#
# Tuktoyaktuk with city ID:6170031 was found in the Weathermap API
#
# Cefalu with city ID:2525041 was found in the Weathermap API
#
# klokkarvik,no was not found in the Weathermap API
#
# Beckley with city ID:4798308 was found in the Weathermap API
#
# Hamilton with city ID:3573197 was found in the Weathermap API
#
# Gobabis with city ID:3357247 was found in the Weathermap API
#
# marzuq,ly was not found in the Weathermap API
#
# Tautira with city ID:4033557 was found in the Weathermap API
#
# Ulladulla with city ID:2145554 was found in the Weathermap API
#
# Yellowknife with city ID:6185377 was found in the Weathermap API
#
# Berlevag with city ID:780687 was found in the Weathermap API
#
# New Norfolk with city ID:2155415 was found in the Weathermap API
#
# Saldanha with city ID:3361934 was found in the Weathermap API
#
# Victoria with city ID:241131 was found in the Weathermap API
#
# Unai with city ID:3445764 was found in the Weathermap API
#
# villa vazquez,do was not found in the Weathermap API
#
# Madiun with city ID:1636930 was found in the Weathermap API
#
# Haines Junction with city ID:5969025 was found in the Weathermap API
#
# Qaanaaq with city ID:3831208 was found in the Weathermap API
#
# rungata,ki was not found in the Weathermap API
#
# Innisfail with city ID:2162683 was found in the Weathermap API
#
# Luderitz with city ID:3355672 was found in the Weathermap API
#
# Yanam with city ID:1252795 was found in the Weathermap API
#
# Lompoc with city ID:5367788 was found in the Weathermap API
#
# Barra do Garcas with city ID:3470709 was found in the Weathermap API
#
# Olafsvik with city ID:3414079 was found in the Weathermap API
#
# Cidreira with city ID:3466165 was found in the Weathermap API
#
# Paraiso with city ID:3521912 was found in the Weathermap API
#
# Krasnosel'kup with city ID:1502073 was found in the Weathermap API
#
# Esperance with city ID:2071860 was found in the Weathermap API
#
# Georgetown with city ID:2411397 was found in the Weathermap API
#
# amderma,ru was not found in the Weathermap API
#
# Hithadhoo with city ID:1282256 was found in the Weathermap API
#
# Berkakit with city ID:2026777 was found in the Weathermap API
#
# kuche,cn was not found in the Weathermap API
#
# Butaritari with city ID:2110227 was found in the Weathermap API
#
# Paamiut with city ID:3421193 was found in the Weathermap API
#
# Nelson Bay with city ID:2155562 was found in the Weathermap API
#
# Ballina with city ID:2177069 was found in the Weathermap API
#
# Calama with city ID:3897347 was found in the Weathermap API
#
# Portland with city ID:2152667 was found in the Weathermap API
#
# Beringovskiy with city ID:2126710 was found in the Weathermap API
# Angoram with city ID:2100765 was found in the Weathermap API
#
# Katsuura with city ID:2112309 was found in the Weathermap API
#
# vaitupu,wf was not found in the Weathermap API
#
# Samarai with city ID:2132606 was found in the Weathermap API
#
# Hilo with city ID:5855927 was found in the Weathermap API
#
# Remedios with city ID:3701491 was found in the Weathermap API
#
# Bambous Virieux with city ID:1106677 was found in the Weathermap API
#
# illoqqortoormiut,gl was not found in the Weathermap API
#
# Mana with city ID:3381041 was found in the Weathermap API
#
# Srednekolymsk with city ID:2121025 was found in the Weathermap API
#
# San Patricio with city ID:3985168 was found in the Weathermap API
#
# Acapulco de Juarez with city ID:3533462 was found in the Weathermap API
#
# Tiksi with city ID:2015306 was found in the Weathermap API
#
# Talnakh with city ID:1490256 was found in the Weathermap API
#
# Wa with city ID:2294206 was found in the Weathermap API
#
# Bethel with city ID:5282297 was found in the Weathermap API
#
# Bauchi with city ID:2347468 was found in the Weathermap API
#
# Tasiilaq with city ID:3424607 was found in the Weathermap API
#
# hihifo,to was not found in the Weathermap API
#
# Mweka with city ID:207596 was found in the Weathermap API
#
# Ilulissat with city ID:3423146 was found in the Weathermap API
#
# Puerto Colombia with city ID:3671497 was found in the Weathermap API
#
# Lagoa with city ID:3372964 was found in the Weathermap API
#
# Karatsu with city ID:1860063 was found in the Weathermap API
#
# malwan,in was not found in the Weathermap API
#
# Dalwangan with city ID:1715912 was found in the Weathermap API
#
# Mount Isa with city ID:2065594 was found in the Weathermap API
#
# Pemangkat with city ID:1631637 was found in the Weathermap API
#
# Gumdag with city ID:161943 was found in the Weathermap API
#
# Khatanga with city ID:2022572 was found in the Weathermap API
#
# Pindwara with city ID:1259638 was found in the Weathermap API
#
# Lock Haven with city ID:5198635 was found in the Weathermap API
#
# Barrow with city ID:5880054 was found in the Weathermap API
#
# Saint-Francois with city ID:3578441 was found in the Weathermap API
#
# Mackenzie with city ID:6063191 was found in the Weathermap API
#
# Labuhan with city ID:8079926 was found in the Weathermap API
#
# Bengkulu with city ID:1649150 was found in the Weathermap API
#
# attawapiskat,ca was not found in the Weathermap API
#
# Kirakira with city ID:2178753 was found in the Weathermap API
#
# belushya guba,ru was not found in the Weathermap API
#
# Muros with city ID:3115824 was found in the Weathermap API
#
# mys shmidta,ru was not found in the Weathermap API
#
# Chokurdakh with city ID:2126123 was found in the Weathermap API
#
# Issoire with city ID:3012664 was found in the Weathermap API
#
# Ayacucho with city ID:3947019 was found in the Weathermap API
#
# Bredasdorp with city ID:1015776 was found in the Weathermap API
#
# Abu Dhabi with city ID:292968 was found in the Weathermap API
#
# Te Anau with city ID:2181625 was found in the Weathermap API
#
# Yar-Sale with city ID:1486321 was found in the Weathermap API
#
# Hofn with city ID:2630299 was found in the Weathermap API
#
# Baruun-Urt with city ID:2032614 was found in the Weathermap API
#
# Tiznit with city ID:2527087 was found in the Weathermap API
#
# Cabo San Lucas with city ID:3985710 was found in the Weathermap API
#
# Longyearbyen with city ID:2729907 was found in the Weathermap API
#
# meyungs,pw was not found in the Weathermap API
#
# Maxixe with city ID:1039536 was found in the Weathermap API
#
# lolua,tv was not found in the Weathermap API
#
# aakirkeby,dk was not found in the Weathermap API
#
# Baharly with city ID:162158 was found in the Weathermap API
#
# Ugoofaaru with city ID:1337619 was found in the Weathermap API
#
# Ancud with city ID:3899695 was found in the Weathermap API
#
# Nishihara with city ID:1855342 was found in the Weathermap API
#
# Zavodskoy with city ID:2012623 was found in the Weathermap API
#
# Babati with city ID:161312 was found in the Weathermap API
#
# Elliot Lake with city ID:5947866 was found in the Weathermap API
#
# Casa Nova with city ID:3402621 was found in the Weathermap API
#
# tumannyy,ru was not found in the Weathermap API
#
# Tapes with city ID:3446880 was found in the Weathermap API
#
# kralendijk,an was not found in the Weathermap API
#
# Mustang with city ID:4543352 was found in the Weathermap API
#
# Vostok with city ID:2013279 was found in the Weathermap API
#
# samalaeulu,ws was not found in the Weathermap API
#
# lasa,cn was not found in the Weathermap API
#
# Rochester with city ID:5134086 was found in the Weathermap API
#
# Arraial do Cabo with city ID:3471451 was found in the Weathermap API
#
# Peterhead with city ID:2640351 was found in the Weathermap API
#
# Mossamedes with city ID:3347019 was found in the Weathermap API
#
# Husavik with city ID:2629833 was found in the Weathermap API
#
# Abdanan with city ID:145233 was found in the Weathermap API
#
# Balkhash with city ID:1525798 was found in the Weathermap API
#
# Geraldton with city ID:2070998 was found in the Weathermap API
#
# karaton,kz was not found in the Weathermap API
#
# Tuatapere with city ID:2180815 was found in the Weathermap API
#
# Shingu with city ID:1847947 was found in the Weathermap API
#
# Pangkalanbuun with city ID:1632694 was found in the Weathermap API
#
# Ribeira Grande with city ID:3372707 was found in the Weathermap API
#
# Jianning with city ID:1783763 was found in the Weathermap API
#
# Ahipara with city ID:2194098 was found in the Weathermap API
#
# Los Llanos de Aridane with city ID:2514651 was found in the Weathermap API
#
# Porbandar with city ID:1259395 was found in the Weathermap API
#
# Iralaya with city ID:3608828 was found in the Weathermap API
#
# Kholodnyy with city ID:2124611 was found in the Weathermap API
#
# Bilibino with city ID:2126682 was found in the Weathermap API
#
# dubenskiy,ru was not found in the Weathermap API
#
# Clyde River with city ID:5924351 was found in the Weathermap API
#
# Coffs Harbour with city ID:2171085 was found in the Weathermap API
#
# Narsaq with city ID:3421719 was found in the Weathermap API
#
# Atar with city ID:2381334 was found in the Weathermap API
#
# Imeni Poliny Osipenko with city ID:2023584 was found in the Weathermap API
#
# Ouesso with city ID:2255564 was found in the Weathermap API
#
# saleaula,ws was not found in the Weathermap API
#
# Carnarvon with city ID:2074865 was found in the Weathermap API
#
# Ormara with city ID:1168700 was found in the Weathermap API
#
# Sinnamary with city ID:3380290 was found in the Weathermap API
#
# East London with city ID:1006984 was found in the Weathermap API
#
# Kastamonu with city ID:743881 was found in the Weathermap API
#
# San Cristobal with city ID:3651949 was found in the Weathermap API
#
# Henties Bay with city ID:3356832 was found in the Weathermap API
#
# Port Elizabeth with city ID:964420 was found in the Weathermap API
#
# nizhneyansk,ru was not found in the Weathermap API
#
# Macapa with city ID:3396016 was found in the Weathermap API
#
# OEstersund with city ID:2685750 was found in the Weathermap API
#
# Taoudenni with city ID:2450173 was found in the Weathermap API
#
# Tura with city ID:2014833 was found in the Weathermap API
#
# Mezen with city ID:527321 was found in the Weathermap API
#
# Chase with city ID:5920381 was found in the Weathermap API
#
# Grindavik with city ID:3416888 was found in the Weathermap API
#
# Port Keats with city ID:2063039 was found in the Weathermap API
#
# Saint George with city ID:3573061 was found in the Weathermap API
#
# Jyvaskyla with city ID:655194 was found in the Weathermap API
#
# Finote Selam with city ID:337712 was found in the Weathermap API
#
# Karratha with city ID:6620339 was found in the Weathermap API
#
# Betafo with city ID:1066514 was found in the Weathermap API
#
# Alice Town with city ID:3572924 was found in the Weathermap API
#
# Obligado with city ID:3437637 was found in the Weathermap API
#
# yaan,cn was not found in the Weathermap API
#
# barentsburg,sj was not found in the Weathermap API
#
# Fujin with city ID:2037375 was found in the Weathermap API
#
# Sambava with city ID:1056899 was found in the Weathermap API
#
# Atbasar with city ID:1526038 was found in the Weathermap API
#
# Am Timan with city ID:245338 was found in the Weathermap API
#
# Aykhal with city ID:2027296 was found in the Weathermap API
#
# Namatanai with city ID:2090021 was found in the Weathermap API
#
# Kishtwar with city ID:1266475 was found in the Weathermap API
# Sitka with city ID:5557293 was found in the Weathermap API
#
# babanusah,sd was not found in the Weathermap API
#
# Batagay-Alyta with city ID:2027042 was found in the Weathermap API
#
# Ulaanbaatar with city ID:2028462 was found in the Weathermap API
#
# Porto Torres with city ID:3170069 was found in the Weathermap API
#
# marcona,pe was not found in the Weathermap API
#
# Caravelas with city ID:3466980 was found in the Weathermap API
#
# Pecos with city ID:5528182 was found in the Weathermap API
#
# Helong with city ID:2036933 was found in the Weathermap API
#
# Cockburn Town with city ID:3576994 was found in the Weathermap API
#
# Cherskiy with city ID:2126199 was found in the Weathermap API
#
# Dawson Creek with city ID:5935804 was found in the Weathermap API
#
# Daokou with city ID:1813775 was found in the Weathermap API
#
# Satuba with city ID:3387987 was found in the Weathermap API
#
# Yinchuan with city ID:1786657 was found in the Weathermap API
#
# Verkhnevilyuysk with city ID:2013639 was found in the Weathermap API
#
# Walvis Bay with city ID:3359638 was found in the Weathermap API
#
# Torbay with city ID:6167817 was found in the Weathermap API
#
# Kroya with city ID:1639337 was found in the Weathermap API
#
# sentyabrskiy,ru was not found in the Weathermap API
#
# umzimvubu,za was not found in the Weathermap API
#
# Talara with city ID:3691582 was found in the Weathermap API
#
# Lewistown with city ID:5197850 was found in the Weathermap API
#
# Ponta do Sol with city ID:3374346 was found in the Weathermap API
#
# Arrondissement d'Arcachon with city ID:6621469 was found in the Weathermap API
#
# Imbituba with city ID:3461370 was found in the Weathermap API
#
# Gijon with city ID:3121424 was found in the Weathermap API
#
# Sovetskiy with city ID:1491230 was found in the Weathermap API
#
# Iqaluit with city ID:5983720 was found in the Weathermap API
#
# Sao Bento with city ID:3388991 was found in the Weathermap API
#
# Lola with city ID:2418092 was found in the Weathermap API
#
# Ostrovnoy with city ID:556268 was found in the Weathermap API
#
# Midland with city ID:6073363 was found in the Weathermap API
#
# Cayenne with city ID:3382160 was found in the Weathermap API
#
# Chumikan with city ID:2025256 was found in the Weathermap API
#
# Constitucion with city ID:4011743 was found in the Weathermap API
#
# Gamba with city ID:2400547 was found in the Weathermap API
#
# Aksu with city ID:1529660 was found in the Weathermap API
#
# Rawson with city ID:3839307 was found in the Weathermap API
#
# Bubaque with city ID:2374583 was found in the Weathermap API
#
# Kinsale with city ID:2963155 was found in the Weathermap API
#
# Honjo with city ID:1862198 was found in the Weathermap API
#
# Kloulklubed with city ID:7671223 was found in the Weathermap API
#
# Palmer with city ID:4946620 was found in the Weathermap API
#
# Nuevo Progreso with city ID:3522526 was found in the Weathermap API
#
# Galich with city ID:562161 was found in the Weathermap API
#
# Tigil with city ID:2120612 was found in the Weathermap API
#
# Maceio with city ID:3395981 was found in the Weathermap API
#
# Touros with city ID:3386213 was found in the Weathermap API
#
# Tessalit with city ID:2449893 was found in the Weathermap API
#
# Zhangye with city ID:1785036 was found in the Weathermap API
#
# Geri with city ID:145964 was found in the Weathermap API
#
# Baculin with city ID:1729469 was found in the Weathermap API
#
# Novyy Urengoy with city ID:1496511 was found in the Weathermap API
#
# Wilmington with city ID:4499379 was found in the Weathermap API
#
# Storforshei with city ID:3145614 was found in the Weathermap API
#
# skiros,gr was not found in the Weathermap API
#
# Nizwa with city ID:286987 was found in the Weathermap API
#
# Wilkie with city ID:6182001 was found in the Weathermap API
#
# Novikovo with city ID:487928 was found in the Weathermap API
#
# faya,td was not found in the Weathermap API
#
# Radovitskiy with city ID:503210 was found in the Weathermap API
#
# Yanzhou with city ID:1787031 was found in the Weathermap API
#
# Sazava with city ID:3066385 was found in the Weathermap API
#
# Jiaojiang with city ID:1809061 was found in the Weathermap API
#
# Svetlogorsk with city ID:485699 was found in the Weathermap API
#
# Baie-Comeau with city ID:5889745 was found in the Weathermap API
#
# Kununurra with city ID:2068110 was found in the Weathermap API
#
# Tanda with city ID:2280995 was found in the Weathermap API
#
# Uyuni with city ID:3901903 was found in the Weathermap API
#
# Upernavik with city ID:3418910 was found in the Weathermap API
#
# Kalmunai with city ID:1242110 was found in the Weathermap API
#
# Paita with city ID:3694112 was found in the Weathermap API
#
# Vyazemskiy with city ID:2013229 was found in the Weathermap API
#
# Nemuro with city ID:2128975 was found in the Weathermap API
#
# Petilia Policastro with city ID:2523825 was found in the Weathermap API
#
# Harper with city ID:2276492 was found in the Weathermap API
#
# Helsinki with city ID:658225 was found in the Weathermap API
#
# Podporozhye with city ID:508034 was found in the Weathermap API
#
# Sao Filipe with city ID:3374210 was found in the Weathermap API
#
# Hailin with city ID:2037075 was found in the Weathermap API
#
# Zhigansk with city ID:2012530 was found in the Weathermap API
#
# Sorong with city ID:1626542 was found in the Weathermap API
#
# Castelnaudary with city ID:3028351 was found in the Weathermap API
#
# Chaozhou with city ID:1815395 was found in the Weathermap API
#
# Klaksvik with city ID:2618795 was found in the Weathermap API
#
# Mpraeso with city ID:2297834 was found in the Weathermap API
#
# wolmaranstad,za was not found in the Weathermap API
#
# Manitouwadge with city ID:6065253 was found in the Weathermap API
#
# choucheng,cn was not found in the Weathermap API
#
# avera,pf was not found in the Weathermap API
#
# Coihueco with city ID:3894406 was found in the Weathermap API
#
# Kamwenge with city ID:232371 was found in the Weathermap API
#
# warqla,dz was not found in the Weathermap API
#
# Oytal with city ID:1520281 was found in the Weathermap API
#
# Riyadh with city ID:108410 was found in the Weathermap API
#
# samusu,ws was not found in the Weathermap API
#
# Port Hardy with city ID:6111862 was found in the Weathermap API
#
# Buzuluk with city ID:570427 was found in the Weathermap API
#
# Iracoubo with city ID:3381428 was found in the Weathermap API
#
# Elizabeth City with city ID:4465088 was found in the Weathermap API
#
# Stolin with city ID:621277 was found in the Weathermap API
#
# Wattegama with city ID:1224061 was found in the Weathermap API
#
# satitoa,ws was not found in the Weathermap API
#
# Tombouctou with city ID:2449066 was found in the Weathermap API
#
# Lagos with city ID:2267226 was found in the Weathermap API
#
# Zelenets with city ID:463880 was found in the Weathermap API
#
# buariki,ki was not found in the Weathermap API
#
# Ixtapa with city ID:4004293 was found in the Weathermap API
#
# Yulara with city ID:6355222 was found in the Weathermap API
#
# Bathsheba with city ID:3374083 was found in the Weathermap API
#
# Merauke with city ID:2082539 was found in the Weathermap API
#
# Amapa with city ID:3407762 was found in the Weathermap API
#
# Jumla with city ID:1283285 was found in the Weathermap API
#
# Arlit with city ID:2447513 was found in the Weathermap API
#
# Adrar with city ID:2508807 was found in the Weathermap API
#
# Neustrelitz with city ID:2864005 was found in the Weathermap API
#
# Hermiston with city ID:5731070 was found in the Weathermap API
#
# Oktyabrskiy with city ID:515879 was found in the Weathermap API
#
# Chenzhou with city ID:1815059 was found in the Weathermap API
#
# Parkes with city ID:2153778 was found in the Weathermap API
#
# Havre-Saint-Pierre with city ID:5972291 was found in the Weathermap API
#
# Pimentel with city ID:3693584 was found in the Weathermap API
#
# Bariloche with city ID:7647007 was found in the Weathermap API
#
# Englehart with city ID:5948844 was found in the Weathermap API
#
# Port Macquarie with city ID:2152659 was found in the Weathermap API
#
# Sungaipenuh with city ID:1625929 was found in the Weathermap API
#
# Maun with city ID:933366 was found in the Weathermap API
#
# Cuamba with city ID:1047660 was found in the Weathermap API
#
# Ujjain with city ID:1253914 was found in the Weathermap API
#
# Moindou with city ID:2140466 was found in the Weathermap API
#
# Ust-Nera with city ID:2120048 was found in the Weathermap API
#
# Mocuba with city ID:1024312 was found in the Weathermap API
#
# Massakory with city ID:2428228 was found in the Weathermap API
# Maragogi with city ID:3395458 was found in the Weathermap API
#
# Mlonggo with city ID:1635164 was found in the Weathermap API
#
# Sayat with city ID:1218436 was found in the Weathermap API
#
# Neuquen with city ID:3843123 was found in the Weathermap API
#
# Filingue with city ID:2444995 was found in the Weathermap API
#
# Kangaba with city ID:2455735 was found in the Weathermap API
#
# San Quintin with city ID:3984997 was found in the Weathermap API
#
# Formosa with city ID:3463140 was found in the Weathermap API
#
# Novopokrovka with city ID:2018888 was found in the Weathermap API
#
# Coruripe with city ID:3465329 was found in the Weathermap API
#
# Machali with city ID:3881102 was found in the Weathermap API
#
# Nyurba with city ID:2018735 was found in the Weathermap API
#
# airai,pw was not found in the Weathermap API
#
# Tsiroanomandidy with city ID:1054463 was found in the Weathermap API
#
# Uthal with city ID:1162862 was found in the Weathermap API
#
# Salinopolis with city ID:3389822 was found in the Weathermap API
#
# Dzaoudzi with city ID:921900 was found in the Weathermap API
#
# Nushki with city ID:1168749 was found in the Weathermap API
#
# Severobaykalsk with city ID:2016910 was found in the Weathermap API
#
# Rasulnagar with city ID:1167064 was found in the Weathermap API
#
# Gombong with city ID:1643920 was found in the Weathermap API
#
# Conceicao do Araguaia with city ID:3401845 was found in the Weathermap API
#
# High Level with city ID:5975004 was found in the Weathermap API
#
# Houston with city ID:5977783 was found in the Weathermap API
#
# Suruc with city ID:300075 was found in the Weathermap API
#
# Suntar with city ID:2015913 was found in the Weathermap API
#
# Itarema with city ID:3393692 was found in the Weathermap API
#
# Palana with city ID:2122262 was found in the Weathermap API
#
# Norman Wells with city ID:6089245 was found in the Weathermap API
#
# Mayor Pablo Lagerenza with city ID:3867427 was found in the Weathermap API
#
# Baiao with city ID:3406844 was found in the Weathermap API
#
# Alta Floresta with city ID:6316343 was found in the Weathermap API
#
# Quebec with city ID:6325494 was found in the Weathermap API
#
# grand river south east,mu was not found in the Weathermap API
#
# manzil tamim,tn was not found in the Weathermap API
#
# Saint-Augustin with city ID:6137462 was found in the Weathermap API
#
# Verkhnyaya Inta with city ID:1487332 was found in the Weathermap API
#
# Alofi with city ID:4036284 was found in the Weathermap API
#
# Russell with city ID:2188874 was found in the Weathermap API
#
# Bay Roberts with city ID:5895424 was found in the Weathermap API
#
# Morondava with city ID:1058381 was found in the Weathermap API
#
# Hue with city ID:1580240 was found in the Weathermap API
#
# Jalu with city ID:86049 was found in the Weathermap API
#
# Ola with city ID:2122574 was found in the Weathermap API
#
# Komsomolskiy with city ID:545728 was found in the Weathermap API
#
# Semnan with city ID:116402 was found in the Weathermap API
#
# Saint-Pierre with city ID:935214 was found in the Weathermap API
#
# tubruq,ly was not found in the Weathermap API
#
# birin,dz was not found in the Weathermap API
#
# Ha Tinh with city ID:1581047 was found in the Weathermap API
#
# The Valley with city ID:3573374 was found in the Weathermap API
#
# Khromtau with city ID:609404 was found in the Weathermap API
#
# Lisakovsk with city ID:1521315 was found in the Weathermap API
#
# Aksarka with city ID:1512019 was found in the Weathermap API
#
# Jacareacanga with city ID:3397763 was found in the Weathermap API
#
# Departamento de Maldonado with city ID:3441890 was found in the Weathermap API
#
# Mildura with city ID:2157698 was found in the Weathermap API
#
# Tvoroyri with city ID:2611060 was found in the Weathermap API
#
# Bontang with city ID:1648186 was found in the Weathermap API
#
# Sisimiut with city ID:3419842 was found in the Weathermap API
#
# Kunming with city ID:1804651 was found in the Weathermap API
#
# Ambon with city ID:1651531 was found in the Weathermap API
#
# labutta,mm was not found in the Weathermap API
#
# Puerto del Rosario with city ID:2512186 was found in the Weathermap API
#
# Krasnoshchekovo with city ID:1502066 was found in the Weathermap API
#
# Klyuchi with city ID:1503153 was found in the Weathermap API
#
# Qasigiannguit with city ID:3420768 was found in the Weathermap API
#
# Doka with city ID:376332 was found in the Weathermap API
#
# Nome with city ID:5870133 was found in the Weathermap API
#
# Isla Vista with city ID:5359864 was found in the Weathermap API
#
# Chui with city ID:3443061 was found in the Weathermap API
#
# Port Hawkesbury with city ID:6111867 was found in the Weathermap API
#
# Laguna with city ID:3459094 was found in the Weathermap API
#
# Gernsbach with city ID:2920997 was found in the Weathermap API
#
# Akdepe with city ID:601551 was found in the Weathermap API
#
# Warri with city ID:2319133 was found in the Weathermap API
#
# Tazovsky with city ID:1489853 was found in the Weathermap API
#
# Vicuna with city ID:3868308 was found in the Weathermap API
#
# Mandawar with city ID:1263879 was found in the Weathermap API
#
# Ibra with city ID:287832 was found in the Weathermap API
#
# saint anthony,ca was not found in the Weathermap API
#
# Yerbogachen with city ID:2012956 was found in the Weathermap API
#
# Laviana with city ID:3118685 was found in the Weathermap API
#
# Stephenville Crossing with city ID:6156245 was found in the Weathermap API
#
# requena,pe was not found in the Weathermap API
#
# Rocha with city ID:3440777 was found in the Weathermap API
#
# toliary,mg was not found in the Weathermap API
#
# Vung Tau with city ID:1562414 was found in the Weathermap API
#
# dzhusaly,kz was not found in the Weathermap API
#
# Santa Isabel do Rio Negro with city ID:3662489 was found in the Weathermap API
#
# Saanen with city ID:2658904 was found in the Weathermap API
#
# San Angelo with city ID:5530022 was found in the Weathermap API
#
# Bayburt with city ID:750938 was found in the Weathermap API
#
# karaul,ru was not found in the Weathermap API
#
# Mercedes with city ID:3430708 was found in the Weathermap API
#
# Shimoda with city ID:1852357 was found in the Weathermap API
#
# Vangaindrano with city ID:1054329 was found in the Weathermap API
#
# Brae with city ID:2654970 was found in the Weathermap API
#
# Sibolga with city ID:1213855 was found in the Weathermap API
#
# Khovd with city ID:1516048 was found in the Weathermap API
#
# Itamaraca with city ID:3397963 was found in the Weathermap API
#
# Ngara with city ID:151711 was found in the Weathermap API
#
# Kavieng with city ID:2094342 was found in the Weathermap API
#
# Avanuorri with city ID:779622 was found in the Weathermap API
#
# Manlleu with city ID:3117539 was found in the Weathermap API
#
# San Isidro with city ID:1689663 was found in the Weathermap API
#
# Lavrentiya with city ID:4031637 was found in the Weathermap API
#
# Katangli with city ID:2122783 was found in the Weathermap API
#
# Pacific Grove with city ID:5380437 was found in the Weathermap API
#
# Baykit with city ID:1510689 was found in the Weathermap API
#
# Kota Belud with city ID:1736660 was found in the Weathermap API
#
# Sitio Novo do Tocantins with city ID:3387423 was found in the Weathermap API
#
# Takaka with city ID:2181997 was found in the Weathermap API
#
# San Miguel de Tucuman with city ID:3836873 was found in the Weathermap API
#
# Novi Ligure with city ID:3172170 was found in the Weathermap API
#
# Balaguer with city ID:3128978 was found in the Weathermap API
#
# Vila Franca do Campo with city ID:3372472 was found in the Weathermap API
#
# Ust-Kuyga with city ID:2013921 was found in the Weathermap API
#
# Rovaniemi with city ID:638936 was found in the Weathermap API
#
# Tarauaca with city ID:3661980 was found in the Weathermap API
#
# Aklavik with city ID:5882953 was found in the Weathermap API
#
# Arrondissement de Bastia with city ID:3034639 was found in the Weathermap API
#
# Monte Alegre with city ID:3394605 was found in the Weathermap API
#
# Roxana with city ID:3622036 was found in the Weathermap API
#
# Loyola with city ID:1705489 was found in the Weathermap API
#
# Townsville with city ID:2146142 was found in the Weathermap API
#
# Flinders with city ID:6255012 was found in the Weathermap API
#
# Moron with city ID:2029947 was found in the Weathermap API
#
# Perth with city ID:2063523 was found in the Weathermap API
#
# uwayl,sd was not found in the Weathermap API
#
# Les Cayes with city ID:3728097 was found in the Weathermap API
# Hervey Bay with city ID:2146219 was found in the Weathermap API
#
# Price with city ID:5545269 was found in the Weathermap API
#
# Tateyama with city ID:1850523 was found in the Weathermap API
#
# Bend with city ID:5713587 was found in the Weathermap API
#
# Nasirabad with city ID:1261727 was found in the Weathermap API
#
# Vyartsilya with city ID:470762 was found in the Weathermap API
#
# Keti Bandar with city ID:1174451 was found in the Weathermap API
#
# Samoded with city ID:499025 was found in the Weathermap API
#
# Celestun with city ID:3531368 was found in the Weathermap API
#
# Talcahuano with city ID:3870282 was found in the Weathermap API
#
# Naantali with city ID:645212 was found in the Weathermap API
#
# Macau with city ID:3395998 was found in the Weathermap API
#
# San Luis Rio Colorado with city ID:3985604 was found in the Weathermap API
#
# Humaita with city ID:3664078 was found in the Weathermap API
#
# karpenision,gr was not found in the Weathermap API
#
# Winslow with city ID:5321473 was found in the Weathermap API
#
# Nadadores with city ID:3995154 was found in the Weathermap API
#
# Luwuk with city ID:1637001 was found in the Weathermap API
#
# Villeta with city ID:3665895 was found in the Weathermap API
#
# maarianhamina,fi was not found in the Weathermap API
#
# Matay with city ID:352628 was found in the Weathermap API
#
# Galle with city ID:1246294 was found in the Weathermap API
#
# Poronaysk with city ID:2121909 was found in the Weathermap API
#
# Salalah with city ID:286621 was found in the Weathermap API
#
# Ponta Delgada with city ID:3372783 was found in the Weathermap API
#
# Tingo Maria with city ID:3691348 was found in the Weathermap API
#
# Karachi with city ID:1174872 was found in the Weathermap API
#
# Lamar with city ID:4705086 was found in the Weathermap API
#
# Tomigusuku with city ID:1850108 was found in the Weathermap API
#
# Manavalakurichi with city ID:1263942 was found in the Weathermap API
#
# Muskegon with city ID:5003136 was found in the Weathermap API
#
# Hambantota with city ID:1244926 was found in the Weathermap API
#
# Grand Forks with city ID:5964401 was found in the Weathermap API
#
# Kampong Thom with city ID:1831125 was found in the Weathermap API
#
# Saint-Leu with city ID:6690297 was found in the Weathermap API
#
# Comodoro Rivadavia with city ID:3860443 was found in the Weathermap API
#
# Peshawar with city ID:1168197 was found in the Weathermap API
#
# Kapuskasing with city ID:5989403 was found in the Weathermap API
#
# Egvekinot with city ID:4031742 was found in the Weathermap API
#
# linchuan,cn was not found in the Weathermap API
#
# Coquimbo with city ID:3893629 was found in the Weathermap API
#
# Awjilah with city ID:88533 was found in the Weathermap API
#
# Vincennes with city ID:4266307 was found in the Weathermap API
#
# Tondano with city ID:1623424 was found in the Weathermap API
#
# Shiyan with city ID:1794903 was found in the Weathermap API
#
# Okhotsk with city ID:2122605 was found in the Weathermap API
#
# Pyapon with city ID:1299237 was found in the Weathermap API
#
# Maine Soroa with city ID:2441447 was found in the Weathermap API
#
# Lowestoft with city ID:2643490 was found in the Weathermap API
#
# Khargone with city ID:1266928 was found in the Weathermap API
#
# Cianorte with city ID:3466174 was found in the Weathermap API
#
# Sola with city ID:2134814 was found in the Weathermap API
#
# Bonga with city ID:341742 was found in the Weathermap API
#
# Chippewa Falls with city ID:5248511 was found in the Weathermap API
#
# Xining with city ID:1788852 was found in the Weathermap API
#
# kawana waters,au was not found in the Weathermap API
#
# Rudnogorsk with city ID:2017378 was found in the Weathermap API
#
# Kiskunfelegyhaza with city ID:3049885 was found in the Weathermap API
#
# panjwin,iq was not found in the Weathermap API
#
# Moerai with city ID:4034188 was found in the Weathermap API
#
# Quatre Cocos with city ID:1106643 was found in the Weathermap API
#
# Quimper with city ID:2984701 was found in the Weathermap API
#
# Sakaiminato with city ID:1853174 was found in the Weathermap API
#
# Shahgarh with city ID:1256734 was found in the Weathermap API
#
# Khao Wong with city ID:1609990 was found in the Weathermap API
#
# Dawlatabad with city ID:1142226 was found in the Weathermap API
#
# tanshui,tw was not found in the Weathermap API
#
# Idtig with city ID:1711332 was found in the Weathermap API
#
# Eyl with city ID:60019 was found in the Weathermap API
#
# Golden with city ID:5423294 was found in the Weathermap API
#
# Urumqi with city ID:1529102 was found in the Weathermap API
#
# Ayan with city ID:2027316 was found in the Weathermap API
#
# Sabang with city ID:1214026 was found in the Weathermap API

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city_id": city_id,
    "city_name": city_name,
    "country": country,
    "latitude": latitude,
    "longitude": longitude,
    "weather_date": weather_date,
    "temp": temp,
    "humidity": humidity,
    "cloudiness": cloudiness,
    "wind_speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#      city_id     city_name country  latitude  longitude weather_date   temp  \
# 0  3403687.0       Camocim      BR     -2.90     -40.84     01/24/20  80.55
# 1   769250.0        Kielce      PL     50.87      20.63     01/24/20  29.28
# 2  6165406.0      Thompson      CA     55.74     -97.86     01/24/20  19.40
# 3  3366880.0      Hermanus      ZA    -34.42      19.23     01/24/20  66.54
# 4   962367.0  Richards Bay      ZA    -28.78      32.04     01/24/20  77.70
#
#    humidity  cloudiness  wind_speed
# 0      77.0        92.0        8.25
# 1       1.0         0.0       10.07
# 2      79.0        40.0        6.93
# 3      91.0         0.0        3.00
# 4      78.0        69.0       20.76

# %%
# Make a dataframe that has only non-null values (so linear regression can be done later)
weather_data_values = weather_data.dropna()
weather_data_values = weather_data_values.reset_index(drop=True)
weather_data_values['city_id'] = weather_data_values['city_id'].astype(int)
weather_data_values.head()
# Out:
#    city_id     city_name country  latitude  longitude weather_date   temp  \
# 0  3403687       Camocim      BR     -2.90     -40.84     01/24/20  80.55
# 1   769250        Kielce      PL     50.87      20.63     01/24/20  29.28
# 2  6165406      Thompson      CA     55.74     -97.86     01/24/20  19.40
# 3  3366880      Hermanus      ZA    -34.42      19.23     01/24/20  66.54
# 4   962367  Richards Bay      ZA    -28.78      32.04     01/24/20  77.70
#
#    humidity  cloudiness  wind_speed
# 0      77.0        92.0        8.25
# 1       1.0         0.0       10.07
# 2      79.0        40.0        6.93
# 3      91.0         0.0        3.00
# 4      78.0        69.0       20.76

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs.Temperature in Fahrenheit
weatherDate = weather_data_values['weather_date'][0]
plt.scatter(weather_data_values["latitude"], weather_data_values["temp"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Temperature {weatherDate}")
plt.ylabel("Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Figures/LatitudeVsTemperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity
plt.scatter(weather_data_values["latitude"], weather_data_values["humidity"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {weatherDate}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Figures/LatitudeVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data_values["latitude"], weather_data_values["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {weatherDate}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Figures/LatitudeVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data_values["latitude"], weather_data_values["wind_speed"], marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {weatherDate}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Figures/LatitudeVsWindSpeed.png")

# Show plot
plt.show()

# %%
# # Print out the r-squared value along with the plot.
# x_values = weather_data_values["latitude"]
# y_values = weather_data_values["wind_speed"]
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# plt.xlabel('Latitude')
# plt.ylabel('Wind Speed (mph)')
# print(f"The r-squared is: {rvalue}")
# plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def make_lin_reg_plot(x_values,y_values,x_desc,y_desc,hemisphere,filename):
    # Print out the r-squared value along with the plot.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.title(f"{hemisphere}-\nCity {x_desc} vs. {y_desc} {weatherDate}")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.xlabel(x_desc)
    plt.ylabel(y_desc)
    print(f"The r-squared is: {rvalue}")
    print(line_eq)
    plt.savefig(f'Figures/{filename}')
    plt.show()

# %%
# test the function with a call
#make_lin_reg_plot(weather_data_values["latitude"],weather_data_values["wind_speed"],'Latitude','Wind Speed (mph)')

# %%
# Create Northern and Southern Hemisphere DataFrames
#weather_data_values.info()
crit_north = weather_data_values.latitude >= 0
crit_south = weather_data_values.latitude < 0

north_weather = weather_data_values[crit_north]
south_weather = weather_data_values[crit_south]
north_weather = north_weather.reset_index(drop=True)
south_weather = south_weather.reset_index(drop=True)
#north_weather.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_lin_reg_plot(north_weather["latitude"],north_weather["temp"],\
                  'Latitude','Temperature (Fahrenheit)','Northern Hemisphere',\
                 'NorthHemiLatVsTemp.png')
# Out:
# The r-squared is: -0.855041552378802
# y = -1.4x + 92.44

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
make_lin_reg_plot(south_weather["latitude"],south_weather["temp"],\
                  'Latitude',f'Temperature (Fahrenheit)','Southern Hemisphere',\
                 'SouthHemiLatVsTemp.png')
# Out:
# The r-squared is: 0.37260433438641316
# y = 0.24x + 80.84

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(north_weather["latitude"],north_weather["humidity"],\
                  'Latitude',f'Humidity (%)','Northern Hemisphere',\
                 'NorthHemiLatVsHumidity.png')
# Out:
# The r-squared is: 0.4166057041770779
# y = 0.45x + 56.17

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(south_weather["latitude"],south_weather["humidity"],\
                  'Latitude',f'Humidity (%)','Southern Hemisphere',\
                 'SouthHemiLatVsHumidity.png')
# Out:
# The r-squared is: 0.3021000087925186
# y = 0.49x + 84.39

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(north_weather["latitude"],north_weather["cloudiness"],\
                  'Latitude',f'Cloudiness (%)','Northern Hemisphere',\
                 'NorthHemiLatVsCloudiness.png')
# Out:
# The r-squared is: 0.23248910154289995
# y = 0.45x + 39.35

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(south_weather["latitude"],south_weather["cloudiness"],\
                  'Latitude',f'Cloudiness (%)','Southern Hemisphere',\
                 'SouthHemiLatVsCloudiness.png')
# Out:
# The r-squared is: 0.21342733104064412
# y = 0.6x + 71.02

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(north_weather["latitude"],north_weather["wind_speed"],\
                  'Latitude',f'Wind Speed (mph)','Northern Hemisphere',\
                 'NorthHemiLatVsWindSpeed.png')
# Out:
# The r-squared is: 0.08236535986222566
# y = 0.02x + 7.06

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
make_lin_reg_plot(south_weather["latitude"],south_weather["wind_speed"],\
                  'Latitude',f'Wind Speed (mph)','Southern Hemisphere',\
                 'SouthHemiLatVsWindSpeed.png')
# Out:
# The r-squared is: -0.23420231592386517
# y = -0.1x + 6.96
